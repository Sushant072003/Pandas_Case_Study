# %% [markdown]
# **Datasets :** https://www.kaggle.com/c/titanic/data?select=train.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/Python_dataset/train.csv')

df = pd.DataFrame(data)

# %%
data.dtypes

# %% [markdown]
# **1. Display Top 5 rows of the Dataset**

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **2. Check last 3 rows of the Dataset**

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# **3. Find Shape of our Dataset (rows and Columns)**

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# **4. Getting Information about our Dataset like Total Number rows, Total number of columns, Datatypes of each columns and Memory requirement**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# **5. Get Overall Statistics about the DataFrame**

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# **6. Data Fittering**

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df1 = df[df['Sex']== 'male'][['Name','Age']]

df1.head(10)
# Out:
#                               Name   Age
# 0          Braund, Mr. Owen Harris  22.0
# 4         Allen, Mr. William Henry  35.0
# 5                 Moran, Mr. James   NaN
# 6          McCarthy, Mr. Timothy J  54.0
# 7   Palsson, Master. Gosta Leonard   2.0
# 12  Saundercock, Mr. William Henry  20.0
# 13     Andersson, Mr. Anders Johan  39.0
# 16            Rice, Master. Eugene   2.0
# 17    Williams, Mr. Charles Eugene   NaN
# 20            Fynney, Mr. Joseph J  35.0

# %%
gp = df.groupby('Survived')['Sex'].value_counts()
gp
# Out:
# Survived  Sex
# 0         male      468
#           female     81
# 1         female    233
#           male      109
# Name: count, dtype: int64

# %% [markdown]
# **7. Check Null Values in the Dataset**

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
per_missing = df.isnull().sum()*100/len(df)
per_missing
# df['Age'].mean()
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df = df.drop(['Cabin'],axis=1)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df['Embarked'].fillna('S',inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# **10. Categorical Data Encoding**
# - Since most machine learning models only accept numerical variables, preprocessing the categorical variables becomes a necessary step. We need to convert these encode categorical variables to numbers such that the model is able to understand and extract valuable information.

# %%
df.head()
# Here we see that Sex and Embarked Columns contain categorical value which the machine learning model can't understand
# That why we encoding this into numeric form
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Gender'] = df['Sex'].map({'male':1,'female':0})

# %%
df.insert(5,'Gender',df.pop('Gender'))

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  Gender   Age  \
# 0            1         0       3  Braund, Mr. Owen Harris  male       1  22.0
#
#    SibSp  Parch     Ticket  Fare Embarked
# 0      1      0  A/5 21171  7.25        S

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
data1 = pd.get_dummies(df,columns=['Embarked'],drop_first=True,dtype=int)

# %%
data1.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex  Gender   Age  \
# 0            1         0       3  Braund, Mr. Owen Harris  male       1  22.0
#
#    SibSp  Parch     Ticket  Fare  Embarked_Q  Embarked_S
# 0      1      0  A/5 21171  7.25           0           1

# %% [markdown]
# **11. What is Univariate Analysis?**
# - countplot (discrete , categorical variable)
# - hist/boxplot(Continuous Variable)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# - How Many people Survived and How Many Died ?

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x = df['Survived'])
plt.show()

# %% [markdown]
# - How Many Passengerrs were in first class , second class, third class?

# %%
df['Pclass'].value_counts().sort_index()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Use seaborn's countplot function
sns.countplot(x=df['Pclass'],color='silver')

# Display the plot
plt.show()

# %% [markdown]
# - Number of Male and Female Passengers ?

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Sex'], palette=['green','yellow'])
plt.legend(['Male','Female'])
plt.show()
# Out:
# <ipython-input-46-cce94149e980>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Sex'], palette=['green','yellow'])

# %%
sns.histplot(df['Age'],bins=10,color='grey')
plt.show()

# %%
sns.boxplot(df['Age'],orient='v')
plt.show()

# %% [markdown]
# **12. Bivariate Analysus**

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %% [markdown]
# - who has Better Chance of Survival Male or Female ?

# %%
sns.barplot(data = df,x=df['Sex'],y=df['Survived'])
plt.show()

# %% [markdown]
# - Which Passenger class has Better Cchace of Survial?

# %%
sns.barplot(data=df,x=df['Pclass'],y=df['Survived'])
plt.show()

# %% [markdown]
# **13. Feature Engineering**
# - Feature Engineering is the process of creating new features or transforming existing features to improve the performance of a machine-learning model. It involves selecting relevant information from raw data and transforming it into a format that can be easily understood by a model. The goal is to improve model accuracy by providing more meaningful and relevant information.

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Gender', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df['Family_size'] = df['SibSp']+df['Parch']

df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex  Gender        Age  SibSp  Parch      Ticket   Fare Embarked  \
# 886    male       1  27.000000      0      0      211536  13.00        S
# 887  female       0  19.000000      0      0      112053  30.00        S
# 888  female       0  29.699118      1      2  W./C. 6607  23.45        S
# 889    male       1  26.000000      0      0      111369  30.00        C
# 890    male       1  32.000000      0      0      370376   7.75        Q
#
#      Family_size
# 886            0
# 887            0
# 888            3
# 889            0
# 890            0

# %%
df['Fare_per_person'] = df['Fare'] / (df['Family_size']+1)

df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex  Gender        Age  SibSp  Parch      Ticket   Fare Embarked  \
# 886    male       1  27.000000      0      0      211536  13.00        S
# 887  female       0  19.000000      0      0      112053  30.00        S
# 888  female       0  29.699118      1      2  W./C. 6607  23.45        S
# 889    male       1  26.000000      0      0      111369  30.00        C
# 890    male       1  32.000000      0      0      370376   7.75        Q
#
#      Family_size  Fare_per_person
# 886            0          13.0000
# 887            0          30.0000
# 888            3           5.8625
# 889            0          30.0000
# 890            0           7.7500

# %% [markdown]
# # Pandas Practise set

# %%
import pandas as pd

dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,89,99,37,90,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female']
               }
df1=pd.DataFrame(dict1)
df1
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     37    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# **1. Display Top 3 Rows of the Dataset**

# %%
df1.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %% [markdown]
# **1. Display Last 3 Rows of the Dataset**

# %%
df1.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# **3.Find Shape of our Dataset (Numbres of rows and columns )**

# %%
df1.shape

print("Number of rows :",df1.shape[0])
print("Number of columns :",df1.shape[1])
# Out:
# Number of rows : 7
# Number of columns : 3

# %% [markdown]
# **4.Get informations about our dataset like total no. of rows,columns,datatype  of each columns and memory requirment**

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %% [markdown]
# **5. Check Null Values in the dataset**

# %%
df1.isnull().sum(axis = 0)
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %%
import seaborn as sns

sns.heatmap(df1.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **6. Get Overall Satatistics about the dataframe**

# %%
df1.describe(include='all')
# Out:
#            Name      Marks  Gender
# count         7   7.000000       7
# unique        7        NaN       2
# top     Priyang        NaN  Female
# freq          1        NaN       4
# mean        NaN  85.000000     NaN
# std         NaN  22.022716     NaN
# min         NaN  37.000000     NaN
# 25%         NaN  86.000000     NaN
# 50%         NaN  90.000000     NaN
# 75%         NaN  98.500000     NaN
# max         NaN  99.000000     NaN

# %% [markdown]
# **7. Find Unique Values from The Gender column**

# %%
df1['Gender'].unique()

# nunique = for number
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# **8.Find Number of Unique values from Gender Column**

# %%
df1['Gender'].nunique()
# Out:
# 2

# %% [markdown]
# **9. Display Count of Unique values in Gender column**

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %% [markdown]
# **10. Find total number of students having marks between 90 to 100 (inclusive) Using Between Method**

# %%
df1[df1['Marks']>=90]
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 4   Parshv     90    Male
# 6  Archana     99  Female

# %%
len(df1[(df1['Marks']>=90)  & (df1['Marks']<=100)])
# Out:
# 4

# %%
sum(df1['Marks'].between(90,100))
# Out:
# 4

# %% [markdown]
# **11. Find Average Marks**

# %%
df1['Marks'].mean()
# Out:
# 85.0

# %% [markdown]
# **12. Apply Methods**

# %%
df1['Marks']
# Out:
# 0    98
# 1    89
# 2    99
# 3    37
# 4    90
# 5    83
# 6    99
# Name: Marks, dtype: int64

# %%
def check(x):
  if x>=50:
    return "pass"
  else:
    return "fail"

# %%
df1['Result'] = df1['Marks'].apply(check)

# %%
df1
# Out:
#       Name  Marks  Gender Result
# 0  Priyang     98    Male   pass
# 1   Aadhya     89  Female   pass
# 2   Krisha     99  Female   pass
# 3   Vedant     37    Male   fail
# 4   Parshv     90    Male   pass
# 5   Mittal     83  Female   pass
# 6  Archana     99  Female   pass

# %%
df1['Marks'].apply(lambda x: x/2)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    18.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %%
df1['Name'].apply(len)  # in-built Functiom
# Out:
# 0    7
# 1    6
# 2    6
# 3    6
# 4    6
# 5    6
# 6    7
# Name: Name, dtype: int64

# %% [markdown]
# **13. Map Function**

# %%
df1['Male_Female'] = df1['Gender'].map({'Male':1,'Female':0})
df1
# Out:
#       Name  Marks  Gender Result  Male_Female
# 0  Priyang     98    Male   pass            1
# 1   Aadhya     89  Female   pass            0
# 2   Krisha     99  Female   pass            0
# 3   Vedant     37    Male   fail            1
# 4   Parshv     90    Male   pass            1
# 5   Mittal     83  Female   pass            0
# 6  Archana     99  Female   pass            0

# %% [markdown]
# **14. Drop the Column**

# %%
df1.drop(['Male_Female','Result'],axis=1,inplace=True)
df1
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     37    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %% [markdown]
# **15. Print Name of the Columns**

# %%
df1.columns
# Out:
# Index(['Name', 'Marks', 'Gender'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# **15. Sort The DataFrame as per the Marks Column**

# %%
df1['Marks'].sort_values(ascending=False)
# Out:
# 2    99
# 6    99
# 0    98
# 4    90
# 1    89
# 5    83
# 3    37
# Name: Marks, dtype: int64

# %%
# For muliple columns
df1.sort_values(by=['Marks','Gender'],ascending=True)
# Out:
#       Name  Marks  Gender
# 3   Vedant     37    Male
# 5   Mittal     83  Female
# 1   Aadhya     89  Female
# 4   Parshv     90    Male
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 6  Archana     99  Female

# %% [markdown]
# **17. Display Name & Marks of the Female Students**

# %%
df1[df1['Gender']=='Female'][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya   True
# 2   Krisha   True
# 5   Mittal   True
# 6  Archana   True

# %%
df1[df1['Gender'].isin(['Female'])][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya   True
# 2   Krisha   True
# 5   Mittal   True
# 6  Archana   True

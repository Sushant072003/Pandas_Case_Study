# %% [markdown]
# **Datsets :** https://www.kaggle.com/datasets/andrewmvd/udemy-courses

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/Python_dataset/udemy_courses.csv",parse_dates=['published_timestamp'])

df = pd.DataFrame(data)

# %%
df.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %% [markdown]
# **1. Display Top 5 rows of the Dataset**

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %% [markdown]
# **2. Check last 5 rows of the Dataset**

# %%
df.tail()
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %% [markdown]
# **3. Find Shape of our Dataset (rows and Columns)**

# %%
df.shape
# Out:
# (3678, 12)

# %%
print("Row:",df.shape[0])
print("Columns:",df.shape[1])
# Out:
# Row: 3678
# Columns: 12

# %% [markdown]
# **4. Getting Information about our Dataset like Total Number rows, Total number of columns, Datatypes of each columns and Memory requirement**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %% [markdown]
# **5. Get Overall Statistics about the DataFrame**

# %%
df.describe(include='all')
# Out:
#            course_id                   course_title  \
# count   3.678000e+03                           3678
# unique           NaN                           3663
# top              NaN  Acoustic Blues Guitar Lessons
# freq             NaN                              3
# mean    6.759720e+05                            NaN
# min     8.324000e+03                            NaN
# 25%     4.076925e+05                            NaN
# 50%     6.879170e+05                            NaN
# 75%     9.613555e+05                            NaN
# max     1.282064e+06                            NaN
# std     3.432732e+05                            NaN
#
#                                                       url is_paid  \
# count                                                3678    3678
# unique                                               3672       2
# top     https://www.udemy.com/cfa-level-2-quantitative...    True
# freq                                                    2    3368
# ...

# %% [markdown]
# **6. Check Null Values in the Dataset**

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
print("Any Missing Values? " , df.isnull().any().any())
# Out:
# Any Missing Values?  False

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **7. Check Duplicate Data and Drop them**

# %%
print("Are there any Duplicated value in Data? ",df.duplicated().any())
# Out:
# Are there any Duplicated value in Data?  True

# %%
df.duplicated().sum()
# Out:
# 6

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **8. Find Out Number of Courses per subjects:**

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
gp = df.groupby('subject')['course_id'].count()
gp
# Out:
# subject
# Business Finance       1191
# Graphic Design          602
# Musical Instruments     680
# Web Development        1199
# Name: course_id, dtype: int64

# %%
df['subject'].value_counts()
# Out:
# subject
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: count, dtype: int64

# %%
sns.countplot(x=df['subject'],palette='bright')
plt.xticks(rotation=60)
plt.xlabel('subject',fontsize=14)
plt.ylabel('Number of Courses',fontsize=14)
plt.title('Number of Courses per subjects',fontsize=18)
plt.figure(figsize=(10,5))

plt.show()
# Out:
# <ipython-input-36-1fb2e58d3f60>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['subject'],palette='bright')

# %% [markdown]
# **9. For Which levels, Udemy Courses Providing The Courses**

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject
# 0 2017-01-18 20:58:58+00:00  Business Finance

# %%
df['level'].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
sns.countplot(x=df['level'],palette='bright')
plt.xticks(rotation=60)
plt.xlabel('level',fontsize=14)
plt.ylabel('Number of Courses',fontsize=14)
plt.title('Number of Courses per levels',fontsize=18)
plt.figure(figsize=(10,5))

plt.show()
# Out:
# <ipython-input-40-a9fd5d50d24a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['level'],palette='bright')

# %% [markdown]
# **10. Display the Count of paid and free Courses**

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject
# 0 2017-01-18 20:58:58+00:00  Business Finance

# %%
df['is_paid'].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %%
sns.countplot(x=df['is_paid'],palette='bright')
plt.xticks(rotation=60)
plt.xlabel('is_paid',fontsize=14)
plt.ylabel('Number of Free and Paid Courses',fontsize=14)
plt.title('Number of Free and Paid Courses',fontsize=18)
plt.figure(figsize=(10,5))

plt.show()
# Out:
# <ipython-input-44-cfbd67837402>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['is_paid'],palette='bright')

# %% [markdown]
# **11. Which Course has More lecture (Free and Paid)?**

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.groupby('is_paid')['num_lectures'].max()
# Out:
# is_paid
# False    145
# True     779
# Name: num_lectures, dtype: int64

# %%
sns.barplot(x=df['is_paid'],y=df['num_lectures'] , palette='bright')
plt.show()

# %% [markdown]
# **12. Which Courses have a higher Number of Subscribers Free or Paid ?**

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.groupby('is_paid')['num_subscribers'].max()
# Out:
# is_paid
# False    268923
# True     121584
# Name: num_subscribers, dtype: int64

# %%
sns.barplot(x=df['is_paid'],y=df['num_subscribers'])
plt.show()

# %% [markdown]
# **13. Which levels has the highest Number of Subscribers?**

# %%
df.groupby('level')['num_subscribers'].max().sort_values(ascending=False)
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Intermediate Level     29167
# Expert Level            5172
# Name: num_subscribers, dtype: int64

# %%
sns.barplot(x=df['level'],y=df['num_subscribers'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **14. Find the Most Popular Course Title**

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
gp = df.groupby('course_title')['num_subscribers'].max().sort_values(ascending=False)

gp.head(1)
# Out:
# course_title
# Learn HTML5 Programming From Scratch    268923
# Name: num_subscribers, dtype: int64

# %% [markdown]
# **15. Display 10 Most Popular Courses as per Number of Subscriber**

# %%
gp.head(10)
# Out:
# course_title
# Learn HTML5 Programming From Scratch                          268923
# Coding for Entrepreneurs Basic                                161029
# The Web Developer Bootcamp                                    121584
# Build Your First Website in 1 Week with HTML5 and CSS3        120291
# The Complete Web Developer Course 2.0                         114512
# Free Beginner Electric Guitar Lessons                         101154
# Web Design for Web Developers: Build Beautiful Websites!       98867
# Learn Javascript & JQuery From Scratch                         84897
# Practical PHP: Master the Basics and Code Dynamic Websites     83737
# JavaScript: Understanding the Weird Parts                      79612
# Name: num_subscribers, dtype: int64

# %%
sns.barplot(x = gp.head(10).index,y=gp.head(10))
plt.xticks(rotation=90)
plt.show()

# %%
top_10  = df.sort_values('num_subscribers',ascending=False).head(10)

# %%
sns.barplot(y=top_10['course_title'],x=top_10['num_subscribers'])
plt.show()

# %% [markdown]
# **16. Find the Course Which is Having the Highest Number of Reviews**

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.groupby('subject')['num_reviews'].max().sort_values(ascending=False).head(1)
# Out:
# subject
# Web Development    27445
# Name: num_reviews, dtype: int64

# %%
sns.barplot(x='subject',y='num_reviews',data = df)
# plt.figure(figsize=(4,10))
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# **17. Does Price Affect Number of Reviews?**

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.groupby('price')['num_reviews'].max().sort_values(ascending=False)
# Out:
# price
# 200    27445
# 190    19649
# 175    16976
# 180    15117
# 195    11123
# 0       8629
# 150     8341
# 140     3326
# 30      3137
# 145     2713
# 80      2709
# 120     2408
# 50      2257
# 75      2144
# 100     1724
# 110     1560
# 60      1358
# 115     1190
# 20      1112
# 25      1111
# 35       970
# 95       783
# 185      713
# 105      689
# 65       680
# 165      655
# 90       634
# 40       629
# 85       531
# 55       522
# 155      497
# 125      461
# 45       449
# 70       435
# 160      288
# 135      237
# 170      172
# 130       49
# Name: num_reviews, dtype: int64

# %%
sns.scatterplot(x='price',y='num_reviews',data=df)
plt.show()

# %% [markdown]
# **18. Total Number of Courses Related to python**

# %%
df['course_title'].str.contains('Python').sum()
# Out:
# 29

# %% [markdown]
# **19. Display 10 Most Popular Python Courses as per Number of subcribers**

# %%
py = df[df['course_title'].str.contains('Python')]

# %%
py.groupby('course_title')['num_subscribers'].max().sort_values(ascending=False).head(10)
# Out:
# course_title
# Web Programming with Python                                     35267
# Coding for Entrepreneurs: Learn Python, Django, and More.       23412
# Learn Python and Django: Payment Processing                     17714
# Python and Django Full Stack Web Developer Bootcamp             11832
# Fun and creative web engineering with Python and Web2py         10917
# The Complete Ethical Hacking Course 2.0: Python & Kali Linux     7827
# Complete Python Web Course: Build 8 Python Web Apps              7489
# Try Django 1.9 | Build a Blog and Learn Python's #1 Library      7407
# Python for Beginners: Python Programming Language | Tutorial     6153
# REST APIs with Flask and Python                                  5151
# Name: num_subscribers, dtype: int64

# %%
sns.barplot(y = 'course_title',x = 'num_subscribers',data = py.sort_values('num_subscribers',ascending=False).head(10))
# plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# **20. In Which Year the Highest Number of  Courses were Posted ?**

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df['Year'] = df['published_timestamp'].dt.year

# %%
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#         published_timestamp           subject  Year
# 0 2017-01-18 20:58:58+00:00  Business Finance  2017

# %%
sns.countplot(x='Year',data=df)

plt.show()

# %% [markdown]
# **21. Display Category wise count of posted Subjects[Year wise]**

# %%
df.groupby('Year')['subject'].value_counts()
